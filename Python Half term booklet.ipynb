# %%
print("this is Jhon's first program")
# Out:
# this is Jhon's first program

# %%
name = 'brayden'
school = 'ada'
friend = 'bill'
print(name,school,friend)
# Out:
# brayden ada bill

# %%
town = input('what town do you live in?')
print('I love visiting',town)
# Out:
# what town do you live in?a
# I love a

# %%
first = input('whats your first name')
second = input('whats your last name')
print('hello',first,second)
# Out:
# whats your first namebc
# whats your last namea
# hello bc a

# %%
name = input('whats your name\n')
print('\n',name*5)
# Out:
# whats your name
# a
#
#  aaaaa

# %%
print(1+6)
print(7-5)
print(3*9)
print(7/2)
print(7%2)
# Out:
# 7
# 2
# 27
# 3.5
# 1

# %%
a = 10
b = 2 
c = a/b
print(c)
# Out:
# 5.0

# %%
def primeTest(num):
    
    #hint: start by assuming the number IS a prime
    isPrime = True
    l = []
    
    for i in range(1,num+1):
        
        num2 = num/i
        l.append(num2)
        
    if l[0] == 1:
        isPrime = False
    elif l[1].is_integer():
        isPrime = False
    if l[0] == 2:
        isPrime = True
    else:
        print(i)
        print(num)
        
    return isPrime
    
primeTest(5)
# Out:
# 5
# 5
# True

# %%
a=int(input('Enter number 1:'))
b=int(input('Enter number 2:'))
c=a+b
print('Adding your numbers together gives:',str(c))
# Out:
# Enter number 1:5
# Enter number 2:9
# Adding your numbers together gives: 14

# %%
r = str(input('enter radeos'))
l = str(input('enter hight'))
pi = float(3.14)
print(float(pi)*float(r)*float(r)*float(l))
# Out:
# enter radeos3
# enter hight2
# 56.519999999999996

# %%
a = int(input('first num'))
b = int(input('second um'))
c = int(input('third num'))
if a > b and a > c:
    print(a)
elif b > a and b > c:
    print(b)
else:
    print(c)
# Out:
# first num1
# second um9
# third num4
# 9

# %%
grade = int(input('enter grade'))
if grade == 70:
    print('a')
elif grade >=60 and grade <= 69:
    print('b')
elif grade >= 50 and grade <=59:
    print('c')
elif grade >= 40 and grade <= 49:
    print('d')
else:
    print('u')
# Out:
# enter grade69
# b

# %%
letter = input('enter letter')
times = int(input('enter times'))
print(letter*times)
# Out:
# enter lettert
# enter times7
# ttttttt

# %%
for i in range(1,1000):
    if i % 3 == 0 or i %4 == 0:
        print(i)
# Out:
# 3
# 4
# 6
# 8
# 9
# 12
# 15
# 16
# 18
# 20
# 21
# 24
# 27
# 28
# 30
# 32
# 33
# 36
# 39
# 40
# 42
# 44
# 45
# 48
# 51
# 52
# 54
# 56
# 57
# 60
# 63
# 64
# 66
# 68
# 69
# 72
# 75
# 76
# 78
# 80
# 81
# 84
# 87
# 88
# 90
# 92
# 93
# 96
# 99
# 100
# 102
# 104
# 105
# 108
# 111
# 112
# 114
# 116
# 117
# 120
# 123
# 124
# 126
# 128
# 129
# 132
# 135
# 136
# 138
# 140
# 141
# 144
# 147
# 148
# 150
# 152
# 153
# 156
# 159
# 160
# 162
# 164
# 165
# 168
# 171
# 172
# 174
# 176
# 177
# 180
# 183
# 184
# 186
# 188
# 189
# 192
# 195
# 196
# 198
# 200
# 201
# 204
# 207
# 208
# 210
# 212
# 213
# 216
# 219
# 220
# 222
# 224
# 225
# 228
# 231
# 232
# 234
# 236
# 237
# 240
# 243
# 244
# 246
# 248
# 249
# 252
# 255
# 256
# 258
# 260
# 261
# 264
# 267
# 268
# 270
# 272
# 273
# 276
# 279
# 280
# 282
# 284
# 285
# 288
# 291
# 292
# 294
# 296
# 297
# 300
# 303
# 304
# 306
# 308
# 309
# 312
# 315
# 316
# 318
# 320
# 321
# 324
# 327
# 328
# 330
# 332
# 333
# 336
# 339
# 340
# 342
# 344
# 345
# 348
# 351
# ...

# %%
password = 'apple'
guess = input('enter password')
while guess != password:
    print('wrong password')
    guess = input('enter again')
else:
    print('accsepted')
# Out:
# enter passwordt
# wrong password
# enter againapple
# accsepted

# %%
for i in range(1,500):
    print(i*i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000
# 10201
# 10404
# 10609
# 10816
# 11025
# 11236
# 11449
# 11664
# 11881
# 12100
# 12321
# 12544
# 12769
# 12996
# 13225
# 13456
# 13689
# 13924
# 14161
# 14400
# 14641
# 14884
# 15129
# 15376
# 15625
# 15876
# 16129
# 16384
# 16641
# 16900
# 17161
# 17424
# 17689
# 17956
# 18225
# 18496
# 18769
# 19044
# 19321
# 19600
# 19881
# 20164
# ...

# %%
def circleArea(n):
    pi = float(3.14)
    n = pi*n*n
    c = n
    
    
    
    
circleArea(3)

# %%
def decToBin(x):
    if x == 0:
        return "00000000"
    bits = []
    while x:
        bits.append(str(x % 2))
        x >>= 1
    return "".join(bits).zfill(8)

# %%
def triangle(size):
    spaces=""
    stars=""
    line=""
    for i in range(0,size):
        for j in range(0,(size-1-i)+11-(size-1-i)-i): 
            line=line+" "

        for k in range(0,2*i+1):
            line=line+"*"

        print(line)
        line=""

    triangle(2)
    triangle(3)
    triangle(4)
